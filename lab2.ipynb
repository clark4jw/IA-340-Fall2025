# %% [markdown]
# # lab2

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv ('s3://ia340-fall2025-clark4jw-sldfkjsalgjsdoh/Crime_Incidents_in_2025.csv') #loading my data from S3
df.head(10) #show top 10 rows
# Out:
#              X            Y       CCN              REPORT_DAT     SHIFT  \
# 0  400588.4650  129470.0424   5131706  2025/02/05 05:00:00+00  MIDNIGHT
# 1  405684.5761  135633.8979  10133557  2025/06/30 04:00:00+00  MIDNIGHT
# 2  397581.8300  141846.4300  25079053  2025/05/27 22:19:32+00   EVENING
# 3  399215.8700  138751.2000  25079273  2025/08/11 17:39:31+00       DAY
# 4  397700.5000  137976.2500  25421607  2025/05/05 18:31:00+00       DAY
# 5  396525.4500  138714.0600  25421619  2025/05/05 20:04:15+00   EVENING
# 6  400495.3800  130841.2700  25079455  2025/05/28 17:17:45+00       DAY
# 7  397171.1100  137408.2500  25079796  2025/05/29 07:24:52+00  MIDNIGHT
# 8  396917.7000  138058.7800  25421322  2025/04/15 23:32:40+00   EVENING
# 9  395366.7500  140009.3600  25421413  2025/04/23 12:31:16+00       DAY
#
#    METHOD      OFFENSE                                      BLOCK  \
# 0     GUN     HOMICIDE         800 - 899 BLOCK OF XENIA STREET SE
# ...

# %%
df.shape #show number of rows and columns
# Out:
# (16612, 25)

# %%
df.info() #displays all columns and rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16612 entries, 0 to 16611
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X                     16612 non-null  float64
#  1   Y                     16612 non-null  float64
#  2   CCN                   16612 non-null  int64
#  3   REPORT_DAT            16612 non-null  object
#  4   SHIFT                 16612 non-null  object
#  5   METHOD                16612 non-null  object
#  6   OFFENSE               16612 non-null  object
#  7   BLOCK                 16612 non-null  object
#  8   XBLOCK                16612 non-null  float64
#  9   YBLOCK                16612 non-null  float64
#  10  WARD                  16607 non-null  float64
#  11  ANC                   16607 non-null  object
#  12  DISTRICT              16561 non-null  float64
#  13  PSA                   16561 non-null  float64
# ...

# %%
df.describe() #provides descriptive statistics of each column/variable
# Out:
#                    X              Y           CCN         XBLOCK  \
# count   16612.000000   16612.000000  1.661200e+04   16612.000000
# mean   399223.899504  137978.638332  2.509500e+07  399223.899504
# std      3011.298002    3482.734790  5.500669e+05    3011.298002
# min    390519.560000  127300.240000  5.131706e+06  390519.560000
# 25%    397229.100000  136474.240300  2.503431e+07  397229.100000
# 50%    398916.585000  137848.510000  2.507004e+07  398916.585006
# 75%    401014.009600  139965.547500  2.510658e+07  401014.009567
# max    407806.750900  147250.570000  8.927285e+07  407806.750917
#
#               YBLOCK          WARD      DISTRICT           PSA   CENSUS_TRACT  \
# count   16612.000000  16607.000000  16561.000000  16561.000000   16601.000000
# mean   137978.638332      4.397844      3.681722    372.759133    7635.496295
# std      3482.734790      2.269673      1.825169    182.120965   35568.341322
# ...

# %% [markdown]
# I have 16612 rows and 25 columns. My columns are floats, integers, and object columns.

# %%
df = df.rename(columns={"NEIGHBORHOOD_CLUSTER": "Neighborhood"})  #renames column to easier to type name
df.head() #displays first 5 rows
# Out:
#              X            Y       CCN              REPORT_DAT     SHIFT  \
# 0  400588.4650  129470.0424   5131706  2025/02/05 05:00:00+00  MIDNIGHT
# 1  405684.5761  135633.8979  10133557  2025/06/30 04:00:00+00  MIDNIGHT
# 2  397581.8300  141846.4300  25079053  2025/05/27 22:19:32+00   EVENING
# 3  399215.8700  138751.2000  25079273  2025/08/11 17:39:31+00       DAY
# 4  397700.5000  137976.2500  25421607  2025/05/05 18:31:00+00       DAY
#
#    METHOD      OFFENSE                                      BLOCK  \
# 0     GUN     HOMICIDE         800 - 899 BLOCK OF XENIA STREET SE
# 1     GUN     HOMICIDE           4600 - 4699 BLOCK OF A STREET SE
# 2  OTHERS      ROBBERY        4400 - 4499 BLOCK OF IOWA AVENUE NW
# 3  OTHERS      ROBBERY  1800 - 2199 BLOCK OF NORTH CAPITOL STREET
# 4  OTHERS  THEFT/OTHER           1000 - 1099 BLOCK OF P STREET NW
#
#           XBLOCK         YBLOCK  ...  BLOCK_GROUP CENSUS_TRACT  \
# 0  400588.464990  129470.042358  ...     009801 1       9801.0
# ...

# %%
df.isnull().sum() #examines which columns are missing data
# Out:
# X                      0
# Y                      0
# CCN                    0
# REPORT_DAT             0
# SHIFT                  0
# METHOD                 0
# OFFENSE                0
# BLOCK                  0
# XBLOCK                 0
# YBLOCK                 0
# WARD                   5
# ANC                    5
# DISTRICT              51
# PSA                   51
# Neighborhood           5
# BLOCK_GROUP           11
# CENSUS_TRACT          11
# VOTING_PRECINCT        5
# LATITUDE               0
# LONGITUDE              0
# BID                13327
# START_DATE             2
# END_DATE            1174
# OBJECTID               0
# OCTO_RECORD_ID     16612
# dtype: int64

# %%
df = df[['X','Y','CCN','REPORT_DAT','SHIFT','METHOD','OFFENSE','BLOCK','XBLOCK','YBLOCK','LATITUDE','LONGITUDE']] # keep specific columns 
df.head()
# Out:
#              X            Y       CCN              REPORT_DAT     SHIFT  \
# 0  400588.4650  129470.0424   5131706  2025/02/05 05:00:00+00  MIDNIGHT
# 1  405684.5761  135633.8979  10133557  2025/06/30 04:00:00+00  MIDNIGHT
# 2  397581.8300  141846.4300  25079053  2025/05/27 22:19:32+00   EVENING
# 3  399215.8700  138751.2000  25079273  2025/08/11 17:39:31+00       DAY
# 4  397700.5000  137976.2500  25421607  2025/05/05 18:31:00+00       DAY
#
#    METHOD      OFFENSE                                      BLOCK  \
# 0     GUN     HOMICIDE         800 - 899 BLOCK OF XENIA STREET SE
# 1     GUN     HOMICIDE           4600 - 4699 BLOCK OF A STREET SE
# 2  OTHERS      ROBBERY        4400 - 4499 BLOCK OF IOWA AVENUE NW
# 3  OTHERS      ROBBERY  1800 - 2199 BLOCK OF NORTH CAPITOL STREET
# 4  OTHERS  THEFT/OTHER           1000 - 1099 BLOCK OF P STREET NW
#
#           XBLOCK         YBLOCK   LATITUDE  LONGITUDE
# 0  400588.464990  129470.042358  38.833020 -76.993222
# ...

# %% [markdown]
# I renamed "NEIGHBORHOOD_BLOCK" to "Neighborhood" for easy typing. I found many missing values, so I chose to keep the necessary columns that did not have missing values.

# %%
df['CCN']
# Out:
# 0         5131706
# 1        10133557
# 2        25079053
# 3        25079273
# 4        25421607
#            ...
# 16607    25420387
# 16608    25420731
# 16609    25421539
# 16610    25421842
# 16611    25421919
# Name: CCN, Length: 16612, dtype: int64

# %%
df.sort_values(by='CCN') #sort values by CCN
df.head() #show first 5 rows
# Out:
#              X            Y       CCN              REPORT_DAT     SHIFT  \
# 0  400588.4650  129470.0424   5131706  2025/02/05 05:00:00+00  MIDNIGHT
# 1  405684.5761  135633.8979  10133557  2025/06/30 04:00:00+00  MIDNIGHT
# 2  397581.8300  141846.4300  25079053  2025/05/27 22:19:32+00   EVENING
# 3  399215.8700  138751.2000  25079273  2025/08/11 17:39:31+00       DAY
# 4  397700.5000  137976.2500  25421607  2025/05/05 18:31:00+00       DAY
#
#    METHOD      OFFENSE                                      BLOCK  \
# 0     GUN     HOMICIDE         800 - 899 BLOCK OF XENIA STREET SE
# 1     GUN     HOMICIDE           4600 - 4699 BLOCK OF A STREET SE
# 2  OTHERS      ROBBERY        4400 - 4499 BLOCK OF IOWA AVENUE NW
# 3  OTHERS      ROBBERY  1800 - 2199 BLOCK OF NORTH CAPITOL STREET
# 4  OTHERS  THEFT/OTHER           1000 - 1099 BLOCK OF P STREET NW
#
#           XBLOCK         YBLOCK   LATITUDE  LONGITUDE
# 0  400588.464990  129470.042358  38.833020 -76.993222
# ...

# %%
df.tail() #show last 5 rows
# Out:
#                X          Y       CCN              REPORT_DAT    SHIFT  \
# 16607  406134.57  134786.65  25420387  2025/01/30 02:02:12+00  EVENING
# 16608  399759.38  136609.78  25420731  2025/02/19 12:31:49+00      DAY
# 16609  401297.97  136784.11  25421539  2025/04/29 23:01:35+00  EVENING
# 16610  396307.96  137321.65  25421842  2025/05/15 21:02:18+00  EVENING
# 16611  396330.15  139826.42  25421919  2025/05/21 21:03:07+00  EVENING
#
#        METHOD      OFFENSE                                 BLOCK     XBLOCK  \
# 16607  OTHERS  THEFT/OTHER     520 - 699 BLOCK OF 51ST STREET SE  406134.57
# 16608  OTHERS  THEFT/OTHER        200 - 299 BLOCK OF F STREET NE  399759.38
# 16609  OTHERS  THEFT/OTHER      1400 - 1425 BLOCK OF G STREET NE  401297.97
# 16610  OTHERS  THEFT/OTHER      1800 - 1899 BLOCK OF L STREET NW  396307.96
# 16611  OTHERS  THEFT/OTHER  1800 - 1899 BLOCK OF SUMMIT PLACE NW  396330.15
#
#           YBLOCK   LATITUDE  LONGITUDE
# 16607  134786.65  38.880893 -76.929298
# ...

# %%
df[40:45] #sliced rows 40-45
# Out:
#               X            Y       CCN              REPORT_DAT    SHIFT  \
# 40  407191.9434  136295.4350  25024345  2025/02/19 17:22:48+00      DAY
# 41  398144.4800  138633.9700  25014552  2025/01/31 02:15:14+00  EVENING
# 42  400130.5358  128889.0974  25014619  2025/01/31 02:59:13+00  EVENING
# 43  400886.9908  133004.9529  25015121  2025/02/01 01:11:25+00  EVENING
# 44  394088.4600  138708.7200  25015372  2025/02/01 16:06:25+00      DAY
#
#     METHOD              OFFENSE  \
# 40  OTHERS          THEFT/OTHER
# 41  OTHERS          THEFT/OTHER
# 42  OTHERS  MOTOR VEHICLE THEFT
# 43  OTHERS  MOTOR VEHICLE THEFT
# 44  OTHERS         THEFT F/AUTO
#
#                                               BLOCK         XBLOCK  \
# 40               5800 - 5899 BLOCK OF DIX STREET NE  407191.943365
# 41                   620 - 699 BLOCK OF T STREET NW  398144.480000
# 42               4200 - 4283 BLOCK OF 6TH STREET SE  400130.535806
# ...

# %%
df = df[(df['X']>=0) & (df['Y']>=0) & (df['CCN']>=0)] #filter data
df.describe()
# Out:
#                    X              Y           CCN         XBLOCK  \
# count   16612.000000   16612.000000  1.661200e+04   16612.000000
# mean   399223.899504  137978.638332  2.509500e+07  399223.899504
# std      3011.298002    3482.734790  5.500669e+05    3011.298002
# min    390519.560000  127300.240000  5.131706e+06  390519.560000
# 25%    397229.100000  136474.240300  2.503431e+07  397229.100000
# 50%    398916.585000  137848.510000  2.507004e+07  398916.585006
# 75%    401014.009600  139965.547500  2.510658e+07  401014.009567
# max    407806.750900  147250.570000  8.927285e+07  407806.750917
#
#               YBLOCK      LATITUDE     LONGITUDE
# count   16612.000000  16612.000000  16612.000000
# mean   137978.638332     38.909663    -77.008955
# std      3482.734790      0.031373      0.034721
# min    127300.240000     38.813473    -77.109338
# 25%    136474.240252     38.896116    -77.031952
# 50%    137848.510000     38.908480    -77.012499
# ...

# %% [markdown]
# I selected CCN to be display, I sorted the data by CCN number, and filtered the data by ensuring the X, Y, and CCN columns were above 0
